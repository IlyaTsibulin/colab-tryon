# %% [markdown]
# <a href="https://colab.research.google.com/github/IlyaTsibulin/colab-tryon/blob/main/StableVITON(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/rlawjdghek/StableVITON
# %cd StableVITON

# !pip install torch==2.0.0+cu117 torchvision==0.15.1+cu117 torchaudio==2.0.1 --index-url https://download.pytorch.org/whl/cu117
# !pip install pytorch-lightning==1.5.0 einops opencv-python==4.7.0.72 matplotlib omegaconf albumentations transformers==4.33.2 xformers==0.0.19 triton==2.0.0 open-clip-torch==2.19.0 diffusers==0.20.2 scipy==1.10.1 ipython
# Out:
# Cloning into 'StableVITON'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 143 (delta 16), reused 122 (delta 13), pack-reused 1
# Receiving objects: 100% (143/143), 2.43 MiB | 7.42 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# /content/StableVITON
# Looking in indexes: https://download.pytorch.org/whl/cu117
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 852.6 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 16.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
